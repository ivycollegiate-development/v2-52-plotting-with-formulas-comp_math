# %%
import matplotlib.pyplot as plt
x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]
plt.plot(x,y)
plt.title("Qudratic Relationship")
plt.xlabel("X value")
plt.ylabel("Y value (x*2)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
