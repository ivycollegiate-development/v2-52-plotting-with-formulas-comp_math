# %%
import matplotlib.pyplot as plt
mass_pairs = [(1000, 500), (2000, 500), (3000, 500)]
plt.plot(mass_pairs)
plt.xlabel("Distance (m)")
plt.ylabel("Gravitational Force (N)")
plt.title("Gravitational Force Different Mass Pairs")
plt.yscale('log')
plt.legend()
plt.grid(True)
# Out:
# /tmp/ipykernel_5675/1169561055.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
