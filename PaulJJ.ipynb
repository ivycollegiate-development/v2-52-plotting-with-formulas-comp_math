# %%
import matplotlib.pyplot as plt
mass_pairs = [(1000, 500), (2000, 500), (3000, 500)]
mass1 = (1000, 500)
mass2 = (2000, 500)
mass3 = (3000, 500)
plt.plot(mass1)
plt.plot(mass2)
plt.plot(mass3)

plt.xlabel("Distance (m)")
plt.ylabel("Gravitational Force (N)")
plt.title("Gravitational Force Different Mass Pairs")
plt.yscale('log')
plt.legend()
plt.grid(True)
# Out:
# /tmp/ipykernel_5675/1252050982.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
