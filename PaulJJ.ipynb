# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]
plt.plot(x, y)
plt.xlabel('random bs 1')
plt.ylabel('random bs 2')
plt.title('number go up')
# Out:
# Text(0.5, 1.0, 'number go up')
